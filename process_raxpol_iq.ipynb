# %%
from pathlib import Path

import radarIQ
# Out:
# ## You are using the Python ARM Radar Toolkit (Py-ART), an open source
# ## library for working with weather radar data. Py-ART is partly
# ## supported by the U.S. Department of Energy as part of the Atmospheric
# ## Radiation Measurement (ARM) Climate Research Facility, an Office of
# ## Science user facility.
# ##
# ## If you use this software to prepare a publication, please cite:
# ##
# ##     JJ Helmus and SM Collis, JORS 2016, doi: 10.5334/jors.119

# %%
data = radarIQ.io.raxpolrkc(root=Path().cwd(), caseName='may232024', fileNo=20)
# Out:
# Filename: e:\py\..\may232024\RAXPOL-20240524-001509.292.rkc
# preface = RadarKit/IQ   buildNo = 7
# Pulse data size: 1635098080
# gateCount = 12458   capacity = 36000   downSampledGateCount = 1246
# data offset = 4792
# Reading pulses ...
# Number of pulses: 81235

# %%
print(data.header["desc"]["latitude"])
print(data.header["desc"]["longitude"])
print(data.header["desc"]["heading"])
# Out:
# 34.51249
# -99.56151
# 180.1

# %%
data.ppiToCfrad(azimuthBeamWidthDeg=0.5, beamOverlapDeg=0)
# Out:
# Saved to file e:\py\cases\may232024\out\s0.5o0\cfrad.RAXPOL-20240524-001509.292.nc

# %%
for i in range(175):
    data = radarIQ.io.raxpolrkc(root=Path().cwd(), caseName='may232024', fileNo=i)
    data.ppiToCfrad(azimuthBeamWidthDeg=0.5, beamOverlapDeg=0)
# Out:
# Filename: e:\py\..\may232024\RAXPOL-20240524-000839.083.rkc
# preface = RadarKit/IQ   buildNo = 7
# Pulse data size: 986553792
# gateCount = 12458   capacity = 36000   downSampledGateCount = 1246
# data offset = 4792
# Reading pulses ...
# Number of pulses: 49014
# Saved to file e:\py\cases\may232024\out\s0.5o0\cfrad.RAXPOL-20240524-000839.083.nc
# Filename: e:\py\..\may232024\RAXPOL-20240524-000851.337.rkc
# preface = RadarKit/IQ   buildNo = 7
# Pulse data size: 1595667328
# gateCount = 12458   capacity = 36000   downSampledGateCount = 1246
# data offset = 4792
# Reading pulses ...
# Number of pulses: 79276
# Saved to file e:\py\cases\may232024\out\s0.5o0\cfrad.RAXPOL-20240524-000851.337.nc
# Filename: e:\py\..\may232024\RAXPOL-20240524-000911.157.rkc
# preface = RadarKit/IQ   buildNo = 7
# Pulse data size: 1617143904
# gateCount = 12458   capacity = 36000   downSampledGateCount = 1246
# data offset = 4792
# Reading pulses ...
# Number of pulses: 80343
# ...
